# %% [markdown]
# # Homework 12
#
# https://scikit-learn.org/0.15/modules/scaling_strategies.html#incremental-learning
#
# * Implement a mini batch functionality to train a regressor.
#     - (Optional) If anyone want to do this in a pipeline can do this: https://koaning.github.io/tokenwiser/api/pipeline.html
#
# * Save model, load the model again and test it on `X_test` __Do NOT commit the pickle file__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def test_df():
    df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/car_prices/car_prices.csv', low_memory=False)

    df = df.sample(5000, random_state=100).reset_index(drop=True)
    
    y = df['sellingprice']
    df.drop('sellingprice', axis=1, inplace=True)
    X = df
    
    return X,y

def partial_df():
    df = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/ds602/car_prices/car_prices.csv', low_memory=False)
   
    while(True):
        yield df.sample(100).reset_index(drop=True)
        
gen = partial_df()

# %%
X_test, y_test = test_df()

# %%
# each time you call this you will get a new slice of the dataframe.
next(gen)
# Out:
#     year       make       model                    trim       body  \
# 0   2005    Lincoln    Town Car       Signature Limited      sedan
# 1   2006      Buick  Rendezvous                      CX        SUV
# 2   2012        Ram        1500                      ST   Quad Cab
# 3   2012     Nissan        Leaf                      SL  Hatchback
# 4   2009     Subaru    Forester                    2.5X        SUV
# ..   ...        ...         ...                     ...        ...
# 95  2012       MINI      Cooper                       S  Hatchback
# 96  2011     Nissan      Altima                  3.5 SR      Sedan
# 97  2010  Chevrolet    Traverse                     LT1        suv
# 98  2012      Dodge     Journey  American Value Package        suv
# 99  2010     Nissan        Cube                  1.8 SL      Wagon
#
#    transmission                vin state condition  odometer     color  \
# 0     automatic  1lnhm82w95y601757    nc       3.4   57387.0     white
# 1     automatic  3g5db03l56s642241    ca       2.3   97478.0     white
# 2     automatic  1c6rd6ft6cs157340    ca       2.9   53416.0     white
# 3     automatic  jn1az0cp0ct015851    ca       3.7   38155.0         —
# 4     automatic  jf2sh616x9h744549    fl       3.7  124478.0      gray
# ..          ...                ...   ...       ...       ...       ...
# 95       manual  wmwsv3c56cty27021    in       3.5   26047.0     black
# 96    automatic  1n4bl2ap3bn485740    md       3.5   49983.0    silver
# 97    automatic  1gnlvfed9as101290    mn       3.7   76780.0     white
# 98    automatic  3c4pdcab1ct340849    tx       3.1   47036.0     black
# 99    automatic  jn8az2kr9at159962    pa         3   36396.0  burgundy
#
#    interior                             seller    mmr  sellingprice  \
# 0      gray            fleet lease remarketing   6425          7200
# 1       tan     walters auto sales/service inc   5125          4800
# 2     black            skyhigh remarketing inc  17700         18000
# 3      gray                 nissan-infiniti lt   7450          7500
# 4      gray     mercedes benz of daytona beach   6025          6900
# ..      ...                                ...    ...           ...
# 95    black         craig & landreth pre-owned  16600         15800
# 96     gray        wells fargo dealer services  12550          8000
# 97    black  affordable auto rental/budget rac  12550         13900
# 98    black                 state superior fin  11900         11500
# 99    black          exceptional motorcars ltd   8400          8900
#
#                                    saledate
# 0   Mon Jun 15 2015 02:30:00 GMT-0700 (PDT)
# 1   Tue Feb 03 2015 04:30:00 GMT-0800 (PST)
# 2   Thu Feb 26 2015 04:00:00 GMT-0800 (PST)
# 3   Tue May 19 2015 05:30:00 GMT-0700 (PDT)
# 4   Wed Feb 11 2015 01:40:00 GMT-0800 (PST)
# ..                                      ...
# 95  Thu Feb 12 2015 02:10:00 GMT-0800 (PST)
# 96  Tue May 26 2015 02:30:00 GMT-0700 (PDT)
# 97  Wed Jun 17 2015 03:30:00 GMT-0700 (PDT)
# 98  Thu Jun 18 2015 03:30:00 GMT-0700 (PDT)
# 99  Wed Jan 21 2015 01:30:00 GMT-0800 (PST)
#
# [100 rows x 16 columns]
